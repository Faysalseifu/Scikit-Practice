# %% [markdown]
# # Regression Practice
#
# Explore linear, ridge, lasso, and polynomial regression here.

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures

print('Regression notebook ready')
